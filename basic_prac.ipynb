# %% [markdown]
# Data types: Integer, float, complex, string, bool, None, list, tuple, range, dictionary, set, frozenset, bytes, bytearray, memoryview

# %%
# Data types
num1 = 10    # saves int value (10) in variable num1. This is called variable initialization
num2 = 4.10  # saves float value (4.10) in variable num2
str1 = "Hello" # saves string value ("Hello") in variable str1.
# Anything inside a single (''), double ("") or triple quotes ("""""") will be considered a "string". 

print("num1: ",num1," Type: ",type(num1))  # type() function checks type of data stored in variable
print("num2: ",num2," Type: ",type(num2))
print("str1: ",str1," Type: ",type(str1))
# Out:
# num1:  10  Type:  <class 'int'>
# num2:  4.1  Type:  <class 'float'>
# str1:  Hello  Type:  <class 'str'>

# %%
# Floats detail
pi = 3.14
small_float = 0.001
exp_float = 1.5e2   # 1.5e2 means 1.5*(10)**2  = 150.something which is a float

print("pi: ",pi,type(pi)) # type() checks type of variable
print("small_float: ",small_float,type(small_float))
print("exp_float: ",exp_float,type(exp_float))
# Out:
# pi:  3.14 <class 'float'>
# small_float:  0.001 <class 'float'>
# exp_float:  150.0 <class 'float'>

# %%
# Strings cancatenation
first_name = "Muhammad"
last_name = "Maaz"

print("Full Name: ", first_name + " " + last_name)
# Out:
# Full Name:  Muhammad Maaz

# %%
# String Manipulation

greetings = "Hello! welcome to our community"

print(greetings[0]) # first character will be displayed
print(greetings[0:6]) # characters b/w index 0 and index 6 will be displayed
print(greetings[5:]) # will start from index 5 and goes till the end
print(greetings[:14]) # will  start from index 0 and goes till index 13
# Out:
# H
# Hello!
# ! welcome to our community
# Hello! welcome

# %%
# String multiplication

name = "Muhammad"
print("Name 3 times: ", name*3)
# Out:
# Name 3 times:  MuhammadMuhammadMuhammad

# %% [markdown]
# String formating

# %%
# f strings 

age = 25
height = 165
intro = f"Hello! My name is Muhammad Maaz, I am {age} years old and my height is {height}cm "
print(intro)
# Out:
# Hello! My name is Muhammad Maaz, I am 25 years old and my height is 165cm

# %%
# complex: it is used to store complex (imaginary data) i.e (3j, 8j, 1 +4j etc)
comp_x = 1 + 3j # complex data (1 + 3j) assigned to variable (comp_x)
print(f"Imiginary value : {comp_x}", type(comp_x)) # prints the value in variable (comp_x) and its data type
# Out:
# Imiginary value : (1+3j) <class 'complex'>

# %% [markdown]
# *****************************************hhhhhhhh

# %%
# booleans (True, False)
error_solved = True


print("Error solved:", error_solved, type(error_solved))

if error_solved == True:
    print("Now the program will execute successfully")

else:
    print("Still have some errors")
# Out:
# Error solved: True <class 'bool'>
# Now the program will execute successfully

# %%
# None data type

nothing = None

print("Here is nothing, just check: ", nothing, type(nothing))
# Out:
# Here is nothing, just check:  None <class 'NoneType'>

# %%
if nothing is None:
    print("There is nothing here")
# Out:
# There is nothing here

# %% [markdown]
# **********************************************************************************************************

# %% [markdown]
# Collections:
# List: Ordered, mutable (can add, remove or change any item)

# %%
# Lists

empty_list = []
numbers = [1,3,5,2,6]
mixed_list = [1,4,"Hi",3.4,"Hello","good"]

print(empty_list)
print(numbers)
print(mixed_list)
# Out:
# []
# [1, 3, 5, 2, 6]
# [1, 4, 'Hi', 3.4, 'Hello', 'good']

# %%
# Accessing items of the list
first_item = mixed_list[0]
third_item = mixed_list[3]
last_item = mixed_list[-1]

print("First Item: ", first_item)
print("Third Item: ", third_item)
print("Last Item: ", last_item)
# Out:
# First Item:  1
# Third Item:  3.4
# Last Item:  good

# %%
# Adding elements to a list

even_nums = [2,4,6,8]
print("Before Adding the element: ", even_nums)
even_nums.append(10)  # append() adds elements at the end of the list
print("After adding the element: ",even_nums)

# inset() adds elements at the index that is mentioned to it
even_nums.insert(1,12) , # 1 is index and 12 is the value to be inserted on index 1
print("After adding using inert() method: ", even_nums)
# Out:
# Before Adding the element:  [2, 4, 6, 8]
# After adding the element:  [2, 4, 6, 8, 10]
# After adding using inert() method:  [2, 12, 4, 6, 8, 10]

# %%
# Removing elements from list

odd_num = [1,3,5,7]
print("List items before removing: ", odd_num)

odd_num.pop() # pop() will remove last item from the list
print("List items after removing an item: ", odd_num)

odd_num.remove(3)  # remove() will remove the item that is given as an argument i.e 3

print("After removing item using remove() method: ", odd_num)
# Out:
# List items before removing:  [1, 3, 5, 7]
# List items after removing an item:  [1, 3, 5]
# After removing item using remove() method:  [1, 5]

# %%
# Modify a list

float_num = [1.1,3.5,5.4,6.7]
print("List before modifying: ", float_num)

float_num[2] = 4.4  # will replace element of index 2 with 4.4
print("List after modifying: ", float_num)
# Out:
# List before modifying:  [1.1, 3.5, 5.4, 6.7]
# List after modifying:  [1.1, 3.5, 4.4, 6.7]

# %%
list1 = [1,2,3,4]
list2 = ["Hello", "Hi"]
combined_list = list1 + list2
print(combined_list)
# Out:
# [1, 2, 3, 4, 'Hello', 'Hi']

# %% [markdown]
# Tuple: Ordered, immutable (cannot add remove or change any element)

# %%
empty_tup = ()

# in single tuple comma (,) must be place after the value, otherwise it will not be treated as tuple
single_tup = (3,)
num_tup = (1, 2, 3, 5)
str_tup = ("Hello", "Hi", "Welcome", "Good")

print("Empty tuple: ", empty_tup)
print("Single tuple: ", single_tup)
print("Tuple containing numbers: ", num_tup)
print("Tuple contains text: ", str_tup)
# Out:
# Empty tuple:  ()
# Single tuple:  (3,)
# Tuple containing numbers:  (1, 2, 3, 5)
# Tuple contains text:  ('Hello', 'Hi', 'Welcome', 'Good')

# %%
# Slicing in tuple

sub_num_tup = num_tup[1:3]
print("Sub tuple of numbers: ", sub_num_tup)

sub_str_tup = str_tup = str_tup[:3]
print("Sub tuple of text: ", sub_str_tup)

print(num_tup[:])
# Out:
# Sub tuple of numbers:  (2, 3)
# Sub tuple of text:  ('Hello', 'Hi', 'Welcome')
# (1, 2, 3, 5)

# %%
# unpacking items of a tuple

info = ("Muhammad Maaz", 24, "Engineer")
name, age, profession = info

print("Name:       ", name)
print("Age:        ", age)
print("Profession: ", profession)
# Out:
# Name:        Muhammad Maaz
# Age:         24
# Profession:  Engineer

# %%
tup = ("Hello","Hi")
tup = list(tup)
tup.append("Welcome")
tup = tuple(tup)
print(tup, type(tup))
# Out:
# ('Hello', 'Hi', 'Welcome') <class 'tuple'>

# %%
tuple1 = ("Hi", "Hello")
tuple2 = (1,2,3)
combined_tuple = tuple1 + tuple2
print(combined_tuple)
# Out:
# ('Hi', 'Hello', 1, 2, 3)

# %% [markdown]
#  Dictionary (key, value): Unordered, mutable (can add, update and remove keys )

# %%
# Dictionary using curly braces {}
empty_dict = {}
person_dict = {"name": "Maaz", "age": 25, "gender": "male"} 
print("Person Info: ",person_dict)

# dictionary using dict() function
address_dict = dict(city="Malakand", province="kPK", country="Pakistan")
print("Address: ", address_dict, type(address_dict))
# Out:
# Person Info:  {'name': 'Maaz', 'age': 25, 'gender': 'male'}
# Address:  {'city': 'Malakand', 'province': 'kPK', 'country': 'Pakistan'} <class 'dict'>

# %%
# Accessing items (key-value pairs) in a dictionary
print("Name: ", person_dict["name"])
print("Country: ", address_dict["country"])

# .get() method will return None if the key is not found in the dictionary, instead of raising an error like person_dict["height"] would do.
print("Height1: ", person_dict.get("height1"))
# Out:
# Name:  Maaz
# Country:  Pakistan
# Height1:  None

# %%
# Accessing keys and values of a dictionary
print("************ Keys **********************")
print("Keys of person_dict: ", person_dict.keys())
print("Keys od address_dict: ", address_dict.keys())
print()
print("************ Values **********************")
print("Values of person_dict: ", person_dict.values())
print("Values of address|_dict: ", address_dict.values())
print()
print("************ Items ***********************")
print("Items of person_dict: ",person_dict.items())
print("Items of address_dict: ", address_dict.items())
# Out:
# ************ Keys **********************
# Keys of person_dict:  dict_keys(['name', 'age', 'gender'])
# Keys od address_dict:  dict_keys(['city', 'province', 'country'])
#
# ************ Values **********************
# Values of person_dict:  dict_values(['Maaz', 25, 'male'])
# Values of address|_dict:  dict_values(['Malakand', 'kPK', 'Pakistan'])
#
# ************ Items ***********************
# Items of person_dict:  dict_items([('name', 'Maaz'), ('age', 25), ('gender', 'male')])
# Items of address_dict:  dict_items([('city', 'Malakand'), ('province', 'kPK'), ('country', 'Pakistan')])

# %%
# adding items to a dictionary
print("Before adding items: ", person_dict)

person_dict["height"] = 165
print("After adding items: ", person_dict)
# Out:
# Before adding items:  {'name': 'Maaz', 'age': 25, 'gender': 'male'}
# After adding items:  {'name': 'Maaz', 'age': 25, 'gender': 'male', 'height': 165}

# %%
# Updating values in adictionary
print("Before updating: ", person_dict)
person_dict["age"] = 24                   # will update the value of key "age" from 25 to 24
print("After updating: ", person_dict)
# Out:
# Before updating:  {'name': 'Maaz', 'age': 25, 'gender': 'male', 'height': 165}
# After updating:  {'name': 'Maaz', 'age': 24, 'gender': 'male', 'height': 165}

# %%
# Removing items from a dictionary
print("Before removing items: ", person_dict)
person_dict.pop("height") # will remove the key "height" and its value from the dictionary
print("After removing an item: ", person_dict)
# Out:
# Before removing items:  {'name': 'Maaz', 'age': 24, 'gender': 'male', 'height': 165}
# After removing an item:  {'name': 'Maaz', 'age': 24, 'gender': 'male'}

# %%
# check if a key exists in teh dictionary
if "gender"  in person_dict:
    print("key 'gender' exists in the dictionary")

if "number" not in person_dict:
    print("Key 'number' does not exist in the dictionary")
print()
print("***************************************************")
print("Here is the latest updated dictionary: ", person_dict)
# Out:
# key 'gender' exists in the dictionary
# Key 'number' does not exist in the dictionary
#
# ***************************************************
# Here is the latest updated dictionary:  {'name': 'Maaz', 'age': 24, 'gender': 'male'}

# %% [markdown]
# Set: defined with curly braces {} or set() function. Unordered, does not allow duplicates, mutable

# %%
# Creating set
empty_set = set()

number_set = {1,2,3,2,4,5}    # sets do not allow duplicate values, so 2 will be stored only once in the set

mixed_set = {1, 3.4, "Hello"}

collection_set = {(1,2), "Great", 10}

print("Empty set: ", empty_set)
print("Number set: ", number_set)
print("Mixed set: ", mixed_set)
print("Collection set: ", collection_set)
# Out:
# Empty set:  set()
# Number set:  {1, 2, 3, 4, 5}
# Mixed set:  {1, 'Hello', 3.4}
# Collection set:  {10, (1, 2), 'Great'}

# %%
# Adding items to a set
print("Before adding an element: ", mixed_set)
mixed_set.add("welome")
print("After adding and element: ", mixed_set)
# Out:
# Before adding an element:  {1, 'Hello', 3.4}
# After adding and element:  {'welome', 1, 'Hello', 3.4}

# %%
# Removing items from a set
print("Before removing elements: ", mixed_set)
mixed_set.discard(6) # discard() will remove the specified element from the set, if it is present in the set, if not present it will do nothing and will not raise an error
mixed_set.remove(3.4) # remove() will remove the specified element from the set, if it is present in the set, otherwise it will raise a KeyError
print("After removing elements: ", mixed_set)
# Out:
# Before removing elements:  {'welome', 1, 'Hello', 3.4}
# After removing elements:  {'welome', 1, 'Hello'}

# %%
# applying union, intersection and difference on sets

set1 = {1,2,3,4}
set2 = {3,4,6,7}

union_set = set1.union(set2) # will return a new set that contains all the unique elements from both sets
print("Union of set1 and set2: ", union_set)

intersection_set = set1.intersection(set2) # will return a new set that contains only the common elements in both sets
print("Intersection of set1 and set2: ", intersection_set)

difference_set1 = set1.difference(set2) # will return a set that contains the elements that are present in set1 but not in set2
print("Difference of set1 and set2: ", difference_set1)

difference_set2 = set2.difference(set1) # will return a set that contains the elements that are present in set2 but not inset1
print("Difference of set2 and set1; ", difference_set2)


#  Symmetric_diiference() will return a set that contains the elements that are present in either set1 or set2 but not in both sets i.e not common elements
symmetric_diff = set1.symmetric_difference(set2) 
print("Symmetric difference of set1 and set2: ", symmetric_diff)
# Out:
# Union of set1 and set2:  {1, 2, 3, 4, 6, 7}
# Intersection of set1 and set2:  {3, 4}
# Difference of set1 and set2:  {1, 2}
# Difference of set2 and set1;  {6, 7}
# Symmetric difference of set1 and set2:  {1, 2, 6, 7}

# %% [markdown]
# **********************************************************************************************************

# %% [markdown]
# byte: Sequences of raw 8-bit values. Can beused when dealing with non text data or when we want to encode text in a specific binary format. Such as UTF-8 or ASCII. In addition, it is immutable, once it is created, it cannot be changed (modified) after creation.

# %%
# we can define a byte data by putting a prefix (b) to the data, or by using bytes() function
byte_x = b"Hello"
byte_y = bytes("Good", encoding="utf-8") # while using bytes() in case of a string, we must encode it, otherwise it will raise error
# while in case of itegers, when we use bytes() function, no need to specify the encoding, it will encode it to utf-8 by default
byte_z = bytes(4)
print(byte_x, type(byte_x))
print(byte_y, type(byte_y))
print(byte_z, type(byte_z))

print("*****************************************")
# lets decode the value of byte_y variable back to its original form
decode_byte_y = byte_y.decode()
print("After decoding byte_y back")
print(decode_byte_y, type(decode_byte_y))
# Out:
# b'Hello' <class 'bytes'>
# b'Good' <class 'bytes'>
# b'\x00\x00\x00\x00' <class 'bytes'>
# *****************************************
# After decoding byte_y back
# Good <class 'str'>

# %%
# bytes() can also take a sequence of integers i.e list, tuple or even set with values from 0-255.
# if any of the numbers with in the sequence is greater than 255, it will raise error
byte_list = bytes([3,5,7,212])
print(byte_list, type(byte_list))
byte_tuple = bytes((212, 4,7,9))
print(byte_tuple, type(byte_tuple))
# Out:
# b'\x03\x05\x07\xd4' <class 'bytes'>
# b'\xd4\x04\x07\t' <class 'bytes'>

# %%
# lets try to add some values greater than 255 to the colletions
byte_ls = bytes([233,256,278])
print(byte_ls) # it will raise an error, as the coleection contain values greater than 255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 2
#       1 # lets try to add some values greater than 255 to the colletions
# ----> 2 byte_ls = bytes([233,256,278])
#       3 print(byte_ls) # it will raise an error, as the coleection contain values greater than 255
#
# ValueError: bytes must be in range(0, 256)

# %%
byte_ls1 = bytes({251, 255, 244,12})
print(byte_ls1, type(byte_ls1))
# Out:
# b'\xfb\xf4\x0c\xff' <class 'bytes'>

# %%
# convert string to bytes using another method
text = "example"      # simple string
print(text, type(text)) # prints string with its data type
bytes_obj = text.encode("utf-8")  # string converted to bytes
print(bytes_obj, type(bytes_obj)) # prints bytes with its data type


# reverting back to string
str_obj = bytes_obj.decode()
print("After reverting back to string: ")
print(str_obj, type(str_obj))
# Out:
# example <class 'str'>
# b'example' <class 'bytes'>
# After reverting back to string:
# example <class 'str'>

# %% [markdown]
# Now as we discussed above that bytes() are immutable, so lets check it

# %%
byte_1 = b"Good Morning"
print(byte_1, type(byte_1))   # it will print the byte() obj with its type
change = byte_1[1] = 79       # logic to modify a character
# but it will raise error as we discussed that byte() obj is immutable
print(change)
# Out:
# b'Good Morning' <class 'bytes'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 byte_1 = b"Good Morning"
#       2 print(byte_1, type(byte_1))   # it will print the byte() obj with its type
# ----> 3 change = byte_1[1] = 79       # logic to modify a character
#       4 # but it will raise error as we discussed that byte() obj is immutable
#       5 print(change)
#
# TypeError: 'bytes' object does not support item assignment

# %% [markdown]
# bytearray: If we need a mutable version of bytes, Python provides bytearray(). Through bytearray() we can modify the binary content directly

# %%
# lets define a bytearray
byte_2 = b"Congrates"       # initializes a variable (byte_2) with bytes data type
print(byte_2, type(byte_2)) # displays the variable (byte_2) with its type

# lets modify it using bytearray()
byte_arr = bytearray(byte_2)  # converts byte_2 to bytearray
print(f"before modifying : {byte_arr}")

byte_arr[3] = 71 # modifies the character on index 3 i.e (g) to capital (G)
print(f"After modifying : {byte_arr}")
# Out:
# b'Congrates' <class 'bytes'>
# before modifying : bytearray(b'Congrates')
# After modifying : bytearray(b'ConGrates')

# %% [markdown]
# Note!  Python cannot cancat string (data type) to bytes (data type). Becuase string is saved in the form of Unicode sequence (text), while bytes is saved in the form of raw binary data (0-255)

# %%
# lets check it

my_str = "Good" # string
my_bytes = b"Morning" # bytes
print(my_str, type(my_str))
print(my_bytes, type(my_bytes))

# now lets try to cancat it
concat = my_str + my_bytes  # it will raise an error
print(concat)
# Out:
# Good <class 'str'>
# b'Morning' <class 'bytes'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 9
#       6 print(my_bytes, type(my_bytes))
#       8 # now lets try to cancat it
# ----> 9 concat = my_str + my_bytes  # it will raise an error
#      10 print(concat)
#
# TypeError: can only concatenate str (not "bytes") to str

# %% [markdown]
# To cancat the above two i.e (my_str, my_bytes), we have to specifically encode or decode one of it so that both become the same data type.

# %%
# So now lets try it  (encoding str)
my_str_encode = my_str.encode("utf-8") # encodes the unicode of "my_str" to raw binary (0-255)
# now lets concat
concat = my_str_encode + my_bytes # now it will run, but the type of variable "concat" will be bytes, not str
print(concat, type(concat))
# Out:
# b'GoodMorning' <class 'bytes'>

# %%
# we can also do it in another way i.e (decoding my_bytes)
my_bytes_decode = my_bytes.decode() # decodes "my_encode" from raw binary to a unicode sequence of string
# Now lets concat
concat = my_str + my_bytes_decode # now it will run but the type od variable "concat" will be string, not bytes
print(concat, type(concat))
# Out:
# GoodMorning <class 'str'>

# %% [markdown]
# ********************************************************************************************************

# %% [markdown]
# Operators: Performs computations and logical operations on data

# %%
# Assignment operator(=): Assign values to variables
car = "BMW"      # value(BMW) has been assigned to variable(car)
car_price = 20000000  # value(20000000) has been assigned to variable(car_price)

print("Car Name: ", car)
print("Car Price: ", car_price)
# Out:
# Car Name:  BMW
# Car Price:  20000000

# %%
# Arithmetic operators(+,-,*,/,% etc): Performs mathematical operations like addition, subtraction etc.

number1, number2 = 10, 3
print("Addition: ", number1 + number2)  # (+) returns addition
print("Subtraction: ", number1 - number2) # (-) returns subtraction
print("Multiplication: ", number1 * number2) # (*) returns multiplication
print("Division: ", number1 / number2) # (/) Returns quotient with decimals
print("Reminder: ", number1 % number2) # (%) Returns Reminder
print("Floor Division: ", number1 // number2) # (//) Returns quotient without any decimals
print("Suare of number1: ", number1 ** number2) # (**) is used to take exponent of a number
# Out:
# Addition:  13
# Subtraction:  7
# Multiplication:  30
# Division:  3.3333333333333335
# Reminder:  1
# Floor Division:  3
# Suare of number1:  1000

# %%
# Comparison operators(>,<,>=,<=,!= etc): Compares two or more values, and will return answer in form of (True, False)

price1, price2 = 2000, 40000
print("price1 : ", price1)
print("price2 : ", price2)
print("Is price1 greater than price2? : ", price1 > price2) # (>) used for greater than
print("Is price1 less than price2? : ", price1 < price2) # (<) used for less than
print("Is price1 equal to price2? : ", price1 == price2) # (==) used for equality
print("Is price1 not equal to price2? : ", price1 != price2)# (!=) used for not equal
print("Is price1 greater than or equal to price2? : ", price1 >= price2) # (>=) used for greater than or equal to
print("Is price1 less than or equal to price2? : ", price1 <= price2) # (<=) used for less than or equal to
# Out:
# price1 :  2000
# price2 :  40000
# Is price1 greater than price2? :  False
# Is price1 less than price2? :  True
# Is price1 equal to price2? :  False
# Is price1 not equal to price2? :  True
# Is price1 greater than or equal to price2? :  False
# Is price1 less than or equal to price2? :  True

# %%
# Logical Operators(and, or, not): Used to combine multiple conditions togather

condition1, condition2 = True, False
print("condition1 : ", condition1)
print("conditoin2 : ", condition2)
print("Are both conditions true? : ", condition2 and condition2) # (and) returns true if both cnditions are true.
print("Is either of the condition true? : ", condition1 or condition2) # (or) returns true if either of a condition is true
print("Is condition1 not true? : ", not condition1) # (not) returns true if the condition is not true
print("Is condition2 not ture? : ", not condition2)
# Out:
# condition1 :  True
# conditoin2 :  False
# Are both conditions true? :  False
# Is either of the condition true? :  True
# Is condition1 not true? :  False
# Is condition2 not ture? :  True

# %%
# Membership operators (in, not in): Used to check if a value or variable exists in a collection(list, tuple, string etc) or not
# It will output in boolean (True, False)
name = "Mauz Ahmad"
print("n" in name) # checks if character "n" is present in value of variable "name" or not.
print("M" in name) # checks if character "M" is present in value of variable "name" or not.
print("o" not in name)
# Out:
# False
# True
# True

# %% [markdown]
# **********************************************************************************************************

# %% [markdown]
# Loops: Used to execute some specific lines of code as many times as we need.

# %% [markdown]
# For Loop: Used for iterating over a sequence  i.e (string, list, tuple, dictionary, set etc). it process each element one by one at a time in a readable format.

# %%
# iterating a list containing numbers using for() loop
numbers = [1,3,4,6,2,7]  # list of numbers
for num in numbers:    # iterates each number in the above list and save it in the iterator(num)
    print(num)   # prints the iterator(num)
# Out:
# 1
# 3
# 4
# 6
# 2
# 7

# %%
# range() function: it limits the loops to work on values within a specific range
for val in range(10): # starts from 0, iterates the values that comes in that specific range i.e range (10)
    print(f"value: {val}") # prints each iterated value
# Out:
# value: 0
# value: 1
# value: 2
# value: 3
# value: 4
# value: 5
# value: 6
# value: 7
# value: 8
# value: 9

# %%
# giving more arguments to range() function
for values in range(2,10): # starts from 2, goes upto 10-1 i.e (9)
    print(f"value: {values}") # prints each iterated value
# Out:
# value: 2
# value: 3
# value: 4
# value: 5
# value: 6
# value: 7
# value: 8
# value: 9

# %%
# three arguments to range() function
for value in range(3,15,2): # starts from 3, stops on 15-1 i.e 14 and increments by 2
    print(f"value: {value}") # prints each iterated value
# Out:
# value: 3
# value: 5
# value: 7
# value: 9
# value: 11
# value: 13

# %%
# iterating a string
name = "Muhammad Maaz"  # string
for chars in name:  # iterates each character in the string and save it in the iterator (chars)
    print(chars)    # prints the iterator (cahrs) every time.
# Out:
# M
# u
# h
# a
# m
# m
# a
# d
#
# M
# a
# a
# z

# %%
# enumerate() function in for() loop: Through enumerate() we can iterate values with indxes in a collection (list, tuple etc)
vegetables = ["onion", "garlic", "potato"] # list of vegetables
for index, vegetable in enumerate(vegetables): # iterate indexes, saves them in iterator "index". and iterate vegetables and save them in iterator (vegetable)
    print(f"Vegetable on index {index} : {vegetable}") # prints both the iterators (index and vegetable)
# Out:
# Vegetable on index 0 : onion
# Vegetable on index 1 : garlic
# Vegetable on index 2 : potato

# %%
# performing the above task without enumerate() function
fruits = ["Apple", "Banana", "Mango"]

index = 0  # initialized a counter variable

for fruit in fruits: # iterates elements in fruits and saves them in the iterator (fruit)
    print(f"Fruit on index {index} : {fruit}")  # prints counter (index) and iterator (fruit)
    index += 1    # incrementing index value manually i.e index = index +1
# Out:
# Fruit on index 0 : Apple
# Fruit on index 1 : Banana
# Fruit on index 2 : Mango

# %%
# iterating a dictionary using for() loop
information = {
    "name" : "Muhammad Talha",     # key = "name" , value = "Muhammad Talha"
    "Age" : 9,                     # key = "Age"  , value = 9
    "Height" : "110cm"             # key = "Height", value = "110cm"
}
# iterating over keys
print("iterating over keys:")
for key in information:      # iterate each key in dictionary and saves it in the iterator (key)
    print(f"{key} : {information[key]}") # prints the iterator (key) and also access values using the key
# Out:
# iterating over keys:
# name : Muhammad Talha
# Age : 9
# Height : 110cm

# %%
# performing the above task using keys values pairs
print("iterating over key-value pairs")
for key, value in information.items():
    print(f"{key} : {value}")
# Out:
# iterating over key-value pairs
# name : Muhammad Talha
# Age : 9
# Height : 110cm

# %%
# iterating tuples using for()loop
gen_tup = ("Maaz", 27, "165cm", 0.5) # tuple containing mixed data
for data in gen_tup:
    print(data)
# Out:
# Maaz
# 27
# 165cm
# 0.5

# %%
# iterating the above values with index using for() loop on a tuple
for index, value in enumerate(gen_tup):   # iterate indexes and values and saves it in iterators (index) and (value) respectively
    print(f"value on index {index} : {value}") # printing indexes and its values side by side
# Out:
# value on index 0 : Maaz
# value on index 1 : 27
# value on index 2 : 165cm
# value on index 3 : 0.5

# %%
# performing the above task with out using enumerate() function
ind_counter = 0  # initializing a counter variable for indexes
for value in gen_tup:
    print(f"value on index {ind_counter} : {value}")
    ind_counter += 1
# Out:
# value on index 0 : Maaz
# value on index 1 : 27
# value on index 2 : 165cm
# value on index 3 : 0.5

# %%
# iterating sets using for() loop
info_set = {"Abuzar", "170cm", 22} # tuple with mixed data
for info in info_set: # iterates each value and saves it in the iterator (info)
    print(info) # prints the iterator (info)
# Out:
# 170cm
# Abuzar
# 22

# %%
# iterating the above set values with indexes
for ind_set, value in enumerate(info_set): # iterates indexes and values and saves it in interators (ind_set and value) respectively
    print(f"vlaue on index {ind_set} : {value}") # prints the iterators (ind_set and value) side by side
# Out:
# vlaue on index 0 : 170cm
# vlaue on index 1 : Abuzar
# vlaue on index 2 : 22

# %%
# performing the above task without using enumerate() function
set_ind_counter = 0 # initializes a counter valriable for indexes
for value in info_set: # iterates each value in info_set and saves it in iterator (value)
    print(f"value on index {set_ind_counter} : {value}") # prints indexes (set_ind_counter) and inerator (value) side by side
    set_ind_counter += 1 # incrementing index value manually i.e set_ind_counter = set_ind_counter + 1
# Out:
# value on index 0 : 170cm
# value on index 1 : Abuzar
# value on index 2 : 22

# %% [markdown]
# While loop: While loop runs as long as a specific condition is True.

# %%
# using a while loop to print values from 0 to 4.
count = 0  # initializes a counter variable (count)
while count < 5:   # checks the value of count in each iteration with condition
    print("Count is : ", count)  # prints the value of count
    count += 1  # increments count vlaue to avoid an infinite loop
# Out:
# Count is :  0
# Count is :  1
# Count is :  2
# Count is :  3
# Count is :  4
